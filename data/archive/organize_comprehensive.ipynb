# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from tqdm import tqdm

# %%
interval = [i*1000 for i in range(43)] + [42003]
df_all = pd.DataFrame()
for i in range(len(interval) - 1):
    fileName = f'negative_random_comprehensive/negative_random_{interval[i]:05d}_{interval[i+1]:05d}.csv'
    df = pd.read_csv(fileName)
    df_all = pd.concat([df_all, df])
df_all.to_csv('negative_random_comprehensive.csv', index=False)
df_all
# Out:
#                                            rxn_smiles  label  \
# 0   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...      0
# 1   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...      0
# 2   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...      0
# 3   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...      0
# 4   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...      0
# ..                                                ...    ...
# 6   O=C(NC1CC1)c1ccc(-c2cnc3c(NCCCO)nc(Br)cn23)cc1...      0
# 7   O=C(NC1CC1)c1ccc(-c2cnc3c(NCCCO)nc(Br)cn23)cc1...      0
# 8   O=C(NC1CC1)c1ccc(-c2cnc3c(NCCCO)nc(Br)cn23)cc1...      0
# 9   O=C(NC1CC1)c1ccc(-c2cnc3c(NCCCO)nc(Br)cn23)cc1...      0
# 10  [N-]=[N+]=NCC1CCN(C(c2ccccc2)(c2ccccc2)c2ccccc...      0
#
#                                       true_rxn_smiles  \
# 0   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...
# 1   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...
# 2   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...
# 3   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...
# 4   COC(=O)[C@H](CCCCNC(=O)OCc1ccccc1)NC(=O)Nc1cc(...
# ..                                                ...
# 6   O=C(NC1CC1)c1ccc(-c2cnc3c(NCCCO)nc(Br)cn23)cc1...
# 7   O=C(NC1CC1)c1ccc(-c2cnc3c(NCCCO)nc(Br)cn23)cc1...
# 8   O=C(NC1CC1)c1ccc(-c2cnc3c(NCCCO)nc(Br)cn23)cc1...
# 9   O=C(NC1CC1)c1ccc(-c2cnc3c(NCCCO)nc(Br)cn23)cc1...
# 10  [N-]=[N+]=NCC1CCN(C(c2ccccc2)(c2ccccc2)c2ccccc...
#
#                                      forward_template
# 0   (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
# 1   (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
# 2   (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
# 3   (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
# 4   (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
# ..                                                ...
# 6   (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
# 7   (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
# 8   (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
# 9   (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
# 10  (Br-[c;H0;D3;+0:1](:[#7;a:2]):[c:3]:[#7;a:4])>...
#
# [360334 rows x 4 columns]
