# %%
import pandas as pd

# %%
df = pd.read_excel('41586_2018_BFnature25978_MOESM3_ESM.xlsx', sheet_name='DIels Alder')
df.to_csv('Diels-Alder.csv')
df
# Out:
# c:\Users\yifen\anaconda3\envs\AIHacks\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                      Reaction Smiles         p      logit  \
# 0  C=CC1=CC=CC=C1.C1C=CC=C1>>C1C2CC(C1C=C2)C1=CC=...  0.999968  10.355105
# 1          COC(=O)C=C.C1C=CC=C1>>COC(=O)C1CC2CC1C=C2  0.999993  11.839735
# 2              CCCCCC=C.C1C=CC=C1>>CCCCCC1CC2CC1C=C2  0.997295   5.909931
# 3  CN1C(=O)C=CC1=O.C1C=CC=C1>>CN1C(=O)C2C3CC(C=C3...  0.999996  12.541184
# 4  COC(=O)C#CC(=O)OC.C1C=CC=C1>>COC(=O)C1=C(C2CC1...  0.999996  12.461141
# 5          CNC(=O)C=C.C1C=CC=C1>>CNC(=O)C1CC2CC1C=C2  0.999912   9.332947
# 6  CN(C)C1=CC=C(C=C)C=C1.C1C=CC=C1>>CN(C)C1=CC=C(...  0.999961  10.147809
# 7                    ClC=C.C1C=CC=C1>>ClC1CC2CC1C=C2  0.999853   8.823412
# 8  COC(=O)C=CC(=O)OC.C1C=CC=C1>>COC(=O)C1C2CC(C=C...  0.999988  11.342216
#
#    dienophile LUMO
# 0        -0.073518
# ...

# %%
df = pd.read_excel('41586_2018_BFnature25978_MOESM3_ESM.xlsx', sheet_name='Bromination')
df['Reaction Smiles'] = [
    'NC1=CC=CC=C1.BrBr>>NC1=CC=C(Br)C=C1.Br',
    'OC1=CC=CC=C1.BrBr>>OC1=CC=C(Br)C=C1.Br',
    'OCC1=CC=CC=C1.BrBr>>OCC1=CC=C(Br)C=C1.Br',
    'C(C)(C)CC1=CC=CC=C1.BrBr>>C(C)(C)CC1=CC=C(Br)C=C1.Br',
    'CC1=CC=CC=C1.BrBr>>CC1=CC=C(Br)C=C1.Br',
    'C1=CC=CC=C1.BrBr>>C1=CC=C(Br)C=C1.Br',
    'FC1=CC=CC=C1.BrBr>>FC1=CC=C(Br)C=C1.Br',
    'ClC1=CC=CC=C1.BrBr>>ClC1=CC=C(Br)C=C1.Br',
    'BrC1=CC=CC=C1.BrBr>>BrC1=CC=C(Br)C=C1.Br',
    'IC1=CC=CC=C1.BrBr>>IC1=CC=C(Br)C=C1.Br',
    'COC(=O)C1=CC=CC=C1.BrBr>>COC(=O)C1=CC=C(Br)C=C1.Br',
    'OC(=O)C1=CC=CC=C1.BrBr>>OC(=O)C1=CC=C(Br)C=C1.Br',
    'FC(F)(F)C1=CC=CC=C1.BrBr>>FC(F)(F)C1=CC=C(Br)C=C1.Br',
    'N#CC1=CC=CC=C1.BrBr>>BrC1=CC=C(C=C1)C#N.Br'
]
df = df[['Reaction Smiles', 'Substituent', 'Sigma_p', 'logit score']]
df.to_csv('Bromination.csv')
df
# Out:
# c:\Users\yifen\anaconda3\envs\AIHacks\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                       Reaction Smiles Substituent  Sigma_p  \
# 0              NC1=CC=CC=C1.BrBr>>NC1=CC=C(Br)C=C1.Br           N    -0.30
# 1              OC1=CC=CC=C1.BrBr>>OC1=CC=C(Br)C=C1.Br           O    -0.38
# 2            OCC1=CC=CC=C1.BrBr>>OCC1=CC=C(Br)C=C1.Br          OC    -0.12
# 3   C(C)(C)CC1=CC=CC=C1.BrBr>>C(C)(C)CC1=CC=C(Br)C...    C(C)(C)C    -0.15
# 4              CC1=CC=CC=C1.BrBr>>CC1=CC=C(Br)C=C1.Br           C    -0.14
# 5                C1=CC=CC=C1.BrBr>>C1=CC=C(Br)C=C1.Br           H     0.00
# 6              FC1=CC=CC=C1.BrBr>>FC1=CC=C(Br)C=C1.Br           F     0.15
# 7            ClC1=CC=CC=C1.BrBr>>ClC1=CC=C(Br)C=C1.Br          Cl     0.24
# 8            BrC1=CC=CC=C1.BrBr>>BrC1=CC=C(Br)C=C1.Br          Br     0.26
# ...
